# %%
import quilt

quilt.install("gudbrandtandberg/chesspieces")
# Out:
# ...
# gudbrandtandberg/chesspieces already installed.
# Overwrite? (y/n) n

# %%
# %matplotlib inline
from quilt.data.gudbrandtandberg import chesspieces
from quilt.asa.img import plot

chesspieces.all.q(asa=plot(figsize=(20,20)))
# Out:
# Displaying 100 of 311 images…
