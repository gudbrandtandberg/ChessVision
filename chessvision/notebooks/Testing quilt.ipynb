# %%
import quilt
quilt.install("gudbrandtandberg/chesspieces")
# Out:
# Downloading package metadata...
# gudbrandtandberg/chesspieces already installed.
# Overwrite? (y/n) n

# %%
# %matplotlib inline
from quilt.data.gudbrandtandberg import chesspieces as pieces
from quilt.asa.img import plot

pieces.training.Q(asa=plot(figsize=(20,20)))
# Out:
# Displaying 100 of 242 images…
